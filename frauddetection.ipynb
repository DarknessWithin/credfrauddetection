# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/Users/tanishqsharma/Desktop/JupyterProject1/data/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
import seaborn as sns

# %%
sns.histplot(data['Class'])
# Out:
# <Axes: xlabel='Class', ylabel='Count'>

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
data1 = data[data['Class'] == 1]

# %%
data2 = data[data['Class'] == 0]

# %%
data3 = data2.sample(n=492,random_state=42)

# %%
dataf = pd.concat([data1,data3])

# %%
shuffled_df = dataf.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
shuffled_df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  157278.0  1.984787 -1.937036  0.486613 -1.245536 -2.518536 -0.544524
# 1  153875.0 -0.613696  3.698772 -5.534941  5.620486  1.649263 -2.335145
# 2   56424.0  0.319007 -1.072867 -0.216146  1.494709 -0.627063 -0.761867
# 3  150139.0 -6.682832 -2.714268 -5.774530  1.449792 -0.661836 -1.148650
# 4   85285.0 -6.713407  3.921104 -9.746678  5.148263 -5.151563 -2.099389
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0 -1.819244 -0.074875 -0.659777  ...  0.174011  0.889289  0.218248  0.492384
# 1 -0.907188  0.706362 -3.747646  ...  0.319261 -0.471379 -0.075890 -0.667909
# 2  0.941687 -0.430272 -0.267431  ...  0.332521 -0.022461 -0.537691  0.452072
# 3  0.849686  0.433427 -1.315646  ...  0.220526  1.187013  0.335821  0.215683
# 4 -5.937767  3.578780 -4.684952  ...  0.954272 -0.451086  0.127214 -0.339450
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
X = shuffled_df.drop(['Class'], axis=1)

# %%
Y = shuffled_df['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaler.transform(X_train)
# Out:
# array([[-1.31739925e+00, -2.74370758e+00,  2.47140085e+00, ...,
#          1.69337169e+00,  1.14471936e+00, -3.43454769e-02],
#        [-4.16840645e-01,  6.27617692e-01, -7.39107258e-01, ...,
#         -1.25201976e-01,  1.64014438e-03,  1.56089090e-01],
#        [ 1.08284253e+00,  4.38764786e-01,  8.16967824e-02, ...,
#         -2.85562301e-01,  7.55890722e-02, -4.63623579e-01],
#        ...,
#        [-1.01098759e+00,  2.25053360e-01, -1.19689719e-01, ...,
#         -2.50296648e-01,  1.40789338e-01, -3.01351870e-01],
#        [-8.08242095e-01,  1.20018607e-01,  3.62290866e-03, ...,
#          3.02911098e-01, -1.38590574e-02,  1.09048168e+00],
#        [-2.55129667e-01,  1.68721319e-01, -1.67791538e-01, ...,
#         -1.15710214e-01,  2.44823658e-01, -4.62585316e-01]])

# %%
scaler.transform(X_test)
# Out:
# array([[-0.85264988,  0.24696931, -0.08123324, ..., -0.07926242,
#          0.29770005, -0.43411963],
#        [ 1.10166287, -0.27203485, -0.72614167, ...,  1.0024658 ,
#          0.15925432,  0.1595067 ],
#        [-1.62794521,  0.11407405, -0.21650584, ...,  0.59611171,
#         -0.14044179,  0.6646212 ],
#        ...,
#        [-0.43035427,  0.65049281, -0.62204632, ..., -0.03020441,
#          0.00466495, -0.38216327],
#        [ 1.53004681,  0.79239923, -0.55711688, ..., -0.05822702,
#         -0.17745248, -0.46258532],
#        [-1.60821984,  0.48787023,  0.62299043, ...,  0.44355191,
#          0.90637709, -0.46258532]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
regressor = LogisticRegression(penalty='l1', solver='liblinear')

# %%
regressor.fit(X_train, y_train)
# Out:
# LogisticRegression(penalty='l1', solver='liblinear')

# %%
regressor.score(X_test, y_test)
# Out:
# 0.9390243902439024

# %%
regressor.intercept_
# Out:
# array([-2.53010051])

# %%
type(regressor.coef_)
# Out:
# numpy.ndarray

# %%
(regressor.coef_)[0][27] = 0

# %%
(regressor.coef_)[0][27]
# Out:
# 0.0

# %%
regressor.score(X_test, y_test)
# Out:
# 0.943089430894309
